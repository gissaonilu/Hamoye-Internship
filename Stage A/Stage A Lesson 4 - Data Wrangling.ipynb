# %% [markdown]
# # Data Types and Data Wrangling

# %%
#import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading files of different data types

# %%
#read csv file and save as csv file
csv_file = pd.read_csv('C:/Users/Ganiyat Omotola/Desktop/Hamoye DS Internship/Stage A/sample data/sample data.csv')
csv_file
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
#save files as csv
csv_file.to_csv('file.csv', index = False)

# %%
#read excel files
excel_file = pd.read_excel('C:/Users/Ganiyat Omotola/Desktop/Hamoye DS Internship/Stage A/sample data/sample data.xlsx')
excel_file
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                            Online Instruction Page
# 4          NaN        NaN                              Sample Data for Excel
# 5          NaN        NaN                                                NaN
# 6          NaN        NaN                                  Related tutorials
# 7          NaN        NaN                                 Named Excel Tables
# 8          NaN        NaN                                    Data Entry Tips
# 9          NaN        NaN                            More Excel Sample Files
# 10         NaN        NaN                                                NaN
# ...

# %%
#save excel file
excel_file.to_excel('file.xlsx', index=False)

# %%
#read table from webpage and save as dataframe
html_file = pd.read_html('https://www.contextures.com/xlSampleData01.html')
html_file
# Out:
# [             0        1         2        3      4         5        6
#  0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
#  1     1/6/2019     East     Jones   Pencil     95      1.99   189.05
#  2    1/23/2019  Central    Kivell   Binder     50     19.99   999.50
#  3     2/9/2019  Central   Jardine   Pencil     36      4.99   179.64
#  4    2/26/2019  Central      Gill      Pen     27     19.99   539.73
#  5    3/15/2019     West   Sorvino   Pencil     56      2.99   167.44
#  6     4/1/2019     East     Jones   Binder     60      4.99   299.40
#  7    4/18/2019  Central   Andrews   Pencil     75      1.99   149.25
#  8     5/5/2019  Central   Jardine   Pencil     90      4.99   449.10
#  9    5/22/2019     West  Thompson   Pencil     32      1.99    63.68
#  10    6/8/2019     East     Jones   Binder     60      8.99   539.40
#  11   6/25/2019  Central    Morgan   Pencil     90      4.99   449.10
# ...

# %%
html_file.to_html('file.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-2058b61d9604> in <module>
# ----> 1 html_file.to_html('file.html')
#
# AttributeError: 'list' object has no attribute 'to_html'
